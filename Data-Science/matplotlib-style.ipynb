# %%
import matplotlib.pyplot as plt

# %%
#Para ter duas linhas num gráfico precisa ser em dois plots diferentes. 
#Os plots seguem um padrão de cores de acordo com a lógica
plt.title('matplotlib')
plt.ylabel('Y')
plt.xlabel('X')

#
plt.plot([4, 5, 6, 7, 8, 9], [2, 2, 3, 8, 8.9, 9], label='blue')
plt.plot([1, 2, 3, 4, 5, 6], [1, 2, 3, 4, 2, 1], label='orange')
plt.legend()
